# %%
print("Rohit")
# Out:
# Rohit

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (1.7.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.22.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rohit\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats

# %%
df = pd.read_csv("Final_data_set_1.csv")

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df = df.drop_duplicates()

# %%
df = df.fillna(df.mean(numeric_only=True))

# %%
for col in df.select_dtypes(include='object'):
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
z = np.abs(stats.zscore(df[numeric_cols], nan_policy='omit'))
df = df[(z < 3).all(axis=1)]

# %%
scaler = MinMaxScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df.to_csv("cleaned_data.csv", index=False)
print("Data cleaned successfully! Saved as cleaned_data.csv.")
# Out:
# Data cleaned successfully! Saved as cleaned_data.csv.
