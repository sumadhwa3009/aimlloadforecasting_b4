# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout

import json
import joblib

# %%
with open("../saved_models/features.json") as f:
    feature_names = json.load(f)

# %%
df = pd.read_csv("../data/processed/final_dataset2.csv", parse_dates=["timestamp"])
df.head()
# Out:
#             timestamp  load_actual  temperature  humidity  dew_point  \
# 0 2014-12-31 23:00:00       9484.0          0.5      96.0       -0.1
# 1 2015-01-01 00:00:00       9484.0          0.1      95.0       -0.5
# 2 2015-01-01 01:00:00       9152.0         -0.2      95.0       -0.9
# 3 2015-01-01 02:00:00       8799.0         -0.4      95.0       -1.2
# 4 2015-01-01 03:00:00       8567.0         -0.6      95.0       -1.3
#
#    solar_generation  wind_generation
# 0             92.66           734.81
# 1             92.66           734.81
# 2             92.66           734.81
# 3             92.66           766.64
# 4             92.66           733.13

# %%
target = "load_actual"

X = df[feature_names]
y = df[target]

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1,1))

# %%
def create_sequences(X, y, lookback=24):
    Xs, ys = [], []
    for i in range(lookback, len(X)):
        Xs.append(X[i-lookback:i])
        ys.append(y[i])
    return np.array(Xs), np.array(ys)

lookback = 24
X_seq, y_seq = create_sequences(X_scaled, y_scaled, lookback)

# %%
train_size = int(len(X_seq) * 0.8)

X_train = X_seq[:train_size]
X_test  = X_seq[train_size:]

y_train = y_seq[:train_size]
y_test  = y_seq[train_size:]

# %%
model = Sequential([
    GRU(64, return_sequences=True, input_shape=(lookback, X_train.shape[2])),
    Dropout(0.2),

    GRU(32),
    Dropout(0.2),

    Dense(16, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 24, 64)         │        13,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 32)             │         9,408 │
# ...

# %%
history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=20,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 0.0180 - val_loss: 0.0139
# Epoch 2/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 0.0136 - val_loss: 0.0125
# Epoch 3/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0131 - val_loss: 0.0125
# Epoch 4/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 0.0129 - val_loss: 0.0127
# Epoch 5/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - loss: 0.0126 - val_loss: 0.0123
# Epoch 6/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - loss: 0.0125 - val_loss: 0.0119
# Epoch 7/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0124 - val_loss: 0.0117
# Epoch 8/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - loss: 0.0123 - val_loss: 0.0118
# Epoch 9/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0122 - val_loss: 0.0115
# Epoch 10/20
# 1972/1972 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.0122 - val_loss: 0.0116
# Epoch 11/20
# ...

# %%
pred_scaled = model.predict(X_test)
pred = scaler_y.inverse_transform(pred_scaled)

y_test_actual = scaler_y.inverse_transform(y_test)
# Out:
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
mae_gru = mean_absolute_error(y_test_actual, pred)
rmse_gru = mean_squared_error(y_test_actual, pred) ** 0.5
mape_gru = np.mean(np.abs((y_test_actual - pred) / y_test_actual)) * 100

print("GRU Results:")
print("MAE:", mae_gru)
print("RMSE:", rmse_gru)
print("MAPE:", mape_gru)
# Out:
# GRU Results:
# MAE: 605.8535952338611
# RMSE: 762.9413715641512
# MAPE: 6.306497458005344

# %%
model.save("../saved_models/gru_model.h5")
joblib.dump(scaler_X, "../saved_models/gru_scaler_X.pkl")
joblib.dump(scaler_y, "../saved_models/gru_scaler_y.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['../saved_models/gru_scaler_y.pkl']

# %%
plt.figure(figsize=(15,5))
plt.plot(y_test_actual[:300], label="Actual")
plt.plot(pred[:300], label="Predicted (GRU)")
plt.legend()
plt.title("GRU Forecast — Actual vs Predicted")
plt.show()
